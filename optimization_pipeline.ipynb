# %%
"""
Here is a complete pipeline for optimizing features and hyper parameters.

AutoML FTW!!!

Some thoughts:
    At this point, many argue that AutoML is inefficient. The computational cost is huge.
    And we can cut back on that with intelligence on the part of Data Scientists.
    However, the same argument could be made about Data Analysis. And yet the benefits of ML 
    in that field are well documented.
    
    Who is working on AutoAutoML???
    
    Recursive.
    
    You silly man! It's turtles all the way down. 


Includes:
    1) Categorical Variables
        -Label Encoding
        -One-Hot Encoding
        -Count Encoding
        -Target Encoding

        NOTE: Ideally we would iterate through trying each of these encodings on EACH categorical feature.
                -That's a lot of iterations!
                -We could reduce this by thinking about the nature of the features.
                -But that would require effort...

    2) Hyperparameter Tuning
        -Test them all!!!
        
    3) Try different feature pairings
        -Just brute force combine them all, see what happens
        -Also, create numerical features
        
    4) Cross Fold Validation
    
    
    

To Do:
    1) Give lots of metrics comparing the various techniques.
    2) Create visualizations comparing the techniques.
    3) Comment about 
    4) Store all the results, so you could add additional tuning as needed









"""
